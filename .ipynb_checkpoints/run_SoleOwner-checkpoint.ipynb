# %%
from SoleOwner import *

# %% [markdown]
# #### Trying the model

# %%
t_end = 3000
nt = 200000

# %%
sol = solve_model(t_end,nt)
# Out:
# Choice of gamma_1 = 10.00
# Running model until t = 3000.000000 s
#  Solution in 23.12 s

# %%
u = sol[0]
lt = sol[1]
f = f_so(u,lt)
effort_stock_plot(sol[0],f,gamma_1,1.1)

# %% [markdown]
# #### Convergence to solution
